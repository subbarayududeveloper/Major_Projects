# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cd "/content/drive/MyDrive/ProjectWork"

# %%
# !pip install -r "/content/drive/MyDrive/ProjectWork/requirements.txt"

# %%
# !python "/content/drive/MyDrive/ProjectWork/train_model1.py"
# Out:
# Using device: cuda
# 🚀 Downloading and preparing RAVDESS dataset...
# Dataset already exists.
# Extracting Features: 100% 1248/1248 [01:59<00:00, 10.45it/s]
# 🚀 Starting training...
# Epoch 1/150 | Train Acc: 15.21% | Test Acc: 15.60%
# Epoch 2/150 | Train Acc: 15.10% | Test Acc: 15.60%
# Epoch 3/150 | Train Acc: 15.62% | Test Acc: 15.60%
# Epoch 4/150 | Train Acc: 15.10% | Test Acc: 15.60%
# Epoch 5/150 | Train Acc: 15.62% | Test Acc: 15.60%
# Epoch 6/150 | Train Acc: 15.31% | Test Acc: 15.60%
# Epoch 7/150 | Train Acc: 15.21% | Test Acc: 15.60%
# Epoch 8/150 | Train Acc: 15.73% | Test Acc: 15.60%
# Epoch 9/150 | Train Acc: 15.21% | Test Acc: 15.60%
# Epoch 10/150 | Train Acc: 15.21% | Test Acc: 15.60%
# Epoch 11/150 | Train Acc: 15.42% | Test Acc: 15.60%
# Epoch 12/150 | Train Acc: 15.73% | Test Acc: 15.60%
# Epoch 13/150 | Train Acc: 15.31% | Test Acc: 15.60%
# Epoch 14/150 | Train Acc: 15.52% | Test Acc: 15.60%
# Epoch 15/150 | Train Acc: 15.21% | Test Acc: 16.00%
# ...

# %%
# !ls "/content/drive/MyDrive/ProjectWork"
# Out:
# accuracy_over_epochs.png  predict_emotion1.py  spike_plots_all_emotions.png
# final_snn_model.pth	  RAVDESS_data	       train_model1.py
# label_encoder.pkl	  requirements.txt
# norm_stats.pkl		  run_app1.py

# %%
# !python "/content/drive/MyDrive/ProjectWork/predict_emotion1.py" "/content/drive/MyDrive/ProjectWork/RAVDESS_data/Actor_01/03-01-01-01-01-02-01.wav"
# Out:
# --> Predicted Emotion: CALM

# %%
# !pip install streamlit pyngrok

# %%
from pyngrok import ngrok

# Replace with your own ngrok auth token
ngrok.set_auth_token("2zawQ5fhVjiUCzoCxxt0sDZUubM_3KuKhpYVH4eeMs1iaQmsC")

# %%
import threading
import time
from pyngrok import ngrok
import os

# Kill previous tunnels if any
ngrok.kill()

# Start the Streamlit app in a background thread
def run_streamlit():
    os.system('streamlit run "/content/drive/MyDrive/ProjectWork/run_app1.py" --server.port 8501')

thread = threading.Thread(target=run_streamlit)
thread.start()

# Wait a few seconds for Streamlit to start
time.sleep(5)

# Create a public URL for port 8501
public_url = ngrok.connect(8501)
print("Your Streamlit app is live at:", public_url)
# Out:
# Your Streamlit app is live at: NgrokTunnel: "https://8f4a66e54f20.ngrok-free.app" -> "http://localhost:8501"
