# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/federative learning
# Out:
# /content/drive/MyDrive/federative learning

# %%
# !ls
# Out:
# Data  foldresults  PPE-6-classes-2  requirements.txt  SequentialLearning

# %%
# !pip install -r requirements.txt
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 17.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 15.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.12.0.88
#     Uninstalling opencv-python-4.12.0.88:
#       Successfully uninstalled opencv-python-4.12.0.88
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 81.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 113.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
# ...

# %%
# !pip install roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="aqozwCeIlurf86oeIq1j")
project = rf.workspace("subbaraydu-federative-learning").project("ppe-6-classes-sdqz3")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !ls
# Out:
# Data  foldresults  PPE-6-classes-2  requirements.txt  SequentialLearning

# %%
# !cp -r "/content/drive/MyDrive/federative learning/PPE-6-classes-2" /content/

# %%
NUM_FOLDS = 3
for fold in range(NUM_FOLDS):
    print(f"Running fold {fold}")
    # !python "/content/drive/MyDrive/federative learning/Data/partition_dataset.py" \
      --dataset_root "/content/PPE-6-classes-2" \
      --output_dir "/content/client_fold_results/fold_{fold}" \
      --num_clients 3 \
      --split_type non-iid-dirichlet \
      --dirichlet_alpha 0.3
# Out:
# Running fold 0
# Partitioned data for 3 clients in /content/client_fold_results/fold_0/
# Running fold 1
# Partitioned data for 3 clients in /content/client_fold_results/fold_1/
# Running fold 2
# Partitioned data for 3 clients in /content/client_fold_results/fold_2/

# %%
for fold in range(3):
    src = f"/content/client_fold_results/fold_{fold}/."
    dst = f"/content/drive/MyDrive/federative learning/foldresults/fold_{fold}/"
    # !cp -r "$src" "$dst"

# %%
# !ls
# Out:
# Data  foldresults  PPE-6-classes-2  requirements.txt  SequentialLearning

# %%
# !ls
# Out:
# Data  foldresults  PPE-6-classes-2  requirements.txt  SequentialLearning

# %%
# !ls
# Out:
# Data  foldresults  PPE-6-classes-2  requirements.txt  SequentialLearning

# %%
# !ls
# Out:
# Data  foldresults  PPE-6-classes-2  requirements.txt  SequentialLearning

# %%
# !ls
# Out:
# Data  foldresults  PPE-6-classes-2  requirements.txt  SequentialLearning

# %%
# !ls
# Out:
# Data  foldresults  PPE-6-classes-2  requirements.txt  SequentialLearning

# %%
# !pip install ultralytics

# %%
# !ls
# Out:
# Data  foldresults  PPE-6-classes-2  requirements.txt  SequentialLearning

# %%
# %cd /content/drive/MyDrive/federative learning/SequentialLearning
# Out:
# /content/drive/MyDrive/federative learning/SequentialLearning

# %%
# !ls
# Out:
#  config.yaml		    'FL_YOLOv8_Project_Outputs(half)'   yolo11n.pt
#  core			     Main.py			        yolov8n.pt
#  federated_learning.log      PPE-6-classes-2
#  FL_YOLOv8_Project_Outputs   train_client.py

# %%
# %cd /content/drive/MyDrive/federative learning/SequentialLearning
# Out:
# /content/drive/MyDrive/federative learning/SequentialLearning

# %%
# !ls
# Out:
#  config.yaml		    'FL_YOLOv8_Project_Outputs(half)'   yolo11n.pt
#  core			     Main.py			        yolov8n.pt
#  federated_learning.log      PPE-6-classes-2
#  FL_YOLOv8_Project_Outputs   train_client.py

# %%
# !nvidia-smi
# Out:
# Sun Sep  7 05:31:27 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %cd /content/drive/MyDrive/federative learning/SequentialLearning
# Out:
# /content/drive/MyDrive/federative learning/SequentialLearning

# %%
# !ls
# Out:
#  config.yaml		    'FL_YOLOv8_Project_Outputs(half)'   yolo11n.pt
#  core			     Main.py			        yolov8n.pt
#  federated_learning.log      PPE-6-classes-2
#  FL_YOLOv8_Project_Outputs   train_client.py

# %%
# %cd /content/drive/MyDrive/federative learning
# Out:
# /content/drive/MyDrive/federative learning

# %%
# !ls
# Out:
# centralized.py	evaluate_models     foldresults      requirements.txt
# Data		evaluation_results  PPE-6-classes-2  SequentialLearning

# %%
# %cd /content/drive/MyDrive/federative learning/SequentialLearning
# Out:
# /content/drive/MyDrive/federative learning/SequentialLearning

# %%
cd /content/drive/MyDrive/federative\ learning/SequentialLearning
# Out:
# /content/drive/MyDrive/federative learning/SequentialLearning

# %%
# !python Main.py
# Out:
# 2025-09-07 06:01:27,330 [INFO] ===== Federated Learning Round 1/2 =====
# 2025-09-07 06:01:27,803 [INFO] === Training Round 1 ===
# 2025-09-07 06:01:27,804 [INFO] client1 starting with weights: FL_YOLOv8_Project_Outputs/global_model_checkpoints/global_model_r0.pt
# New https://pypi.org/project/ultralytics/8.3.195 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.149 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !python"/content/drive/MyDrive/federative learning/SequentialLearning/Main.py"
# Out:
# /bin/bash: line 1: python/content/drive/MyDrive/federative learning/SequentialLearning/Main.py: No such file or directory

# %%
# !nvidia-smi
# Out:
#  config.yaml		    'FL_YOLOv8_Project_Outputs(half)'   yolo11n.pt
#  core			     Main.py			        yolov8n.pt
#  federated_learning.log      PPE-6-classes-2
#  FL_YOLOv8_Project_Outputs   train_client.py

# %%
# %cd //content/drive/MyDrive/federative learning/SequentialLearning/FL_YOLOv8_Project_Outputs/global_model_checkpoints
# Out:
# /content/drive/MyDrive/federative learning/SequentialLearning/FL_YOLOv8_Project_Outputs/global_model_checkpoints

# %%
# !ls
# Out:
# federated_learning.log	global_model_r1.pt
# global_model_r0.pt	global_model_r2.pt

# %%
# !python /content/drive/MyDrive/federative\ learning/evaluate_models/evaluate_global_model.py \
  --models_dir /content/drive/MyDrive/federative\ learning/SequentialLearning/FL_YOLOv8_Project_Outputs/global_model_checkpoints \
  --val_yaml /content/drive/MyDrive/federative\ learning/foldresults/fold_0/client1/data.yaml \
  --device cuda
# Out:
# --- Evaluating Model: /content/drive/MyDrive/federative learning/SequentialLearning/FL_YOLOv8_Project_Outputs/global_model_checkpoints/global_model_r0.pt ---
#   Number of classes: 6
#   Class names: ['class_0', 'class_1', 'class_2', 'class_3', 'class_4', 'class_5']
# Ultralytics 8.3.149 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n summary (fused): 72 layers, 3,133,922 parameters, 1,458 gradients
# val: Fast image access ✅ (ping: 0.5±0.1 ms, read: 36.5±7.8 MB/s, size: 99.4 KB)
# val: Scanning /content/drive/MyDrive/federative learning/foldresults/fold_0/client1/valid/labels.cache... 797 images, 14 backgrounds, 0 corrupt: 100% 797/797 [00:00<?, ?it/s]
# Error during evaluation of /content/drive/MyDrive/federative learning/SequentialLearning/FL_YOLOv8_Project_Outputs/global_model_checkpoints/global_model_r0.pt: shape '[1, 144, -1]' is invalid for input of size 448000
#
# ...

# %%
# %cd /content/drive/MyDrive/federative learning
# Out:
# /content/drive/MyDrive/federative learning

# %%
# !ls
# Out:
# centralized.py	 evaluation_results	 PPE-6-classes-2
# Data		 federated_learning.log  requirements.txt
# evaluate_models  foldresults		 SequentialLearning

# %%
# !pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.0 MB/s eta 0:00:00
# ...

# %%
# %cd  /content/drive/MyDrive/federative learning
# Out:
# /content/drive/MyDrive/federative learning

# %%
# !python centralized.py
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# --- Starting Centralized Training for 2 epochs ---
# Ultralytics 8.3.195 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
# Out:
# ls: cannot access '/content/drive/MyDrive/federative learning/FL_YOLOv8_Project_Outputs/global_model_checkpoints': No such file or directory

# %%
# Out:
# /content/drive/MyDrive/federative learning/SequentialLearning/FL_YOLOv8_Project_Outputs/global_model_checkpoints

# %%
# Out:
# total 6.3M
# -rw------- 1 root root 6.3M Jul 26 16:33 global_model_r0.pt
